# %% [markdown]
# # IPL DATA ANALYSIS

# %% [markdown]
# ![](data/ipl.jpg)

# %% [markdown]
# In this project "IPL Data Analysis" we will be analyzing IPL data from https://www.kaggle.com/ramjidoolla/ipl-data-set.
# We will be working on the following csv/xlsx files:
#
#        i) deliveries.csv
#       ii) matches.csv
#      iii) most_runs_average_strikerate.csv
#       iv) Players.csv

# %%
        #importing essential libraries
import pandas as pd #to read the database
import numpy as np #for linear algebra

        # libraries used for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
#reading datasets
matches=pd.read_csv('data\matches.csv')
deliveries=pd.read_csv('data\deliveries.csv')
players=pd.read_csv('data\Players.csv')
runs=pd.read_csv('data\most_runs_average_strikerate.csv')

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
players.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy  24-Feb-91   Right_Hand      Right-arm medium   India
# 1      A Chandila  05-Dec-83   Right_Hand    Right-arm offbreak   India
# 2        A Chopra  19-Sep-77   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaN   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaN   Right_Hand    Right-arm offbreak     NaN

# %%
runs.head()
# Out:
#      batsman  total_runs  out  numberofballs    average  strikerate
# 0    V Kohli        5426  152           4111  35.697368  131.987351
# 1   SK Raina        5386  160           3916  33.662500  137.538304
# 2  RG Sharma        4902  161           3742  30.447205  130.999466
# 3  DA Warner        4717  114           3292  41.377193  143.286756
# 4   S Dhawan        4601  137           3665  33.583942  125.538881

# %%
matches.dtypes
# Out:
# id                  int64
# Season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
matches['team1'].nunique()
# Out:
# 15

# %%
matches['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
matches['team2'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
team1=matches['team1'].groupby(matches['team1']).count()

# %%
team1
# Out:
# team1
# Chennai Super Kings             89
# Deccan Chargers                 43
# Delhi Capitals                   6
# Delhi Daredevils                72
# Gujarat Lions                   14
# Kings XI Punjab                 91
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           83
# Mumbai Indians                 101
# Pune Warriors                   20
# Rajasthan Royals                67
# Rising Pune Supergiant           8
# Rising Pune Supergiants          7
# Royal Challengers Bangalore     85
# Sunrisers Hyderabad             63
# Name: team1, dtype: int64

# %%
team2=matches['team2'].groupby(matches['team2']).count()

# %%
team2
# Out:
# team2
# Chennai Super Kings            75
# Deccan Chargers                32
# Delhi Capitals                 10
# Delhi Daredevils               89
# Gujarat Lions                  16
# Kings XI Punjab                85
# Kochi Tuskers Kerala            7
# Kolkata Knight Riders          95
# Mumbai Indians                 86
# Pune Warriors                  26
# Rajasthan Royals               80
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Royal Challengers Bangalore    95
# Sunrisers Hyderabad            45
# Name: team2, dtype: int64

# %%
total_matches=team1+team2

# %%
total_matches
# Out:
# team1
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
total_matches['Rising Pune Supergiants']=total_matches['Rising Pune Supergiants']+total_matches['Rising Pune Supergiants']
total_matches.drop('Rising Pune Supergiant',inplace = True)

# %%
total_matches['Delhi Capitals']=total_matches['Delhi Capitals']+total_matches['Delhi Daredevils']
total_matches.drop('Delhi Daredevils',inplace=True)

# %%
total_matches
# Out:
# team1
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                 177
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiants         28
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
plt.figure(figsize=(15,8))
total_matches.plot(kind='bar')
plt.xticks(rotation=90)
plt.rc('xtick', labelsize=20)
plt.tight_layout()

# %%
matches['toss_winner'].replace(to_replace="Delhi Daredevils",value="Delhi Capitals",inplace=True)
matches['toss_winner'].replace(to_replace="Rising Pune Supergiants",value="Rising Pune Supergiant",inplace=True)

# %%
toss_winners=matches['toss_winner'].groupby(matches['toss_winner']).count()

# %%
toss_winners
# Out:
# toss_winner
# Chennai Super Kings            89
# Deccan Chargers                43
# Delhi Capitals                 90
# Gujarat Lions                  15
# Kings XI Punjab                81
# Kochi Tuskers Kerala            8
# Kolkata Knight Riders          92
# Mumbai Indians                 98
# Pune Warriors                  20
# Rajasthan Royals               80
# Rising Pune Supergiant         13
# Royal Challengers Bangalore    81
# Sunrisers Hyderabad            46
# Name: toss_winner, dtype: int64

# %%
index=toss_winners.index

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=toss_winners.index,y=toss_winners)
plt.xticks(rotation=90)
plt.rc('xtick',labelsize=20)

# %%
Percentage_toss_win=(toss_winners/total_matches)*100

# %%
matches['winner'].replace(to_replace="Delhi Daredevils",value="Delhi Capitals",inplace=True)
matches['winner'].replace(to_replace="Rising Pune Supergiants",value="Rising Pune Supergiant",inplace=True)

# %%
winners=matches['winner'].groupby(matches['winner']).count()

# %%
winners
# Out:
# winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  77
# Gujarat Lions                   13
# Kings XI Punjab                 82
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           92
# Mumbai Indians                 109
# Pune Warriors                   12
# Rajasthan Royals                75
# Rising Pune Supergiant          15
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             58
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.barplot(x=winners,y=winners.index,orient='h',palette='viridis')
plt.show()

# %%
decision=matches['toss_decision'].groupby(matches['toss_decision']).count()

# %%
decision
# Out:
# toss_decision
# bat      293
# field    463
# Name: toss_decision, dtype: int64

# %%
#winning toss decisions
matches['winner'].groupby(matches['toss_decision']).count()
# Out:
# toss_decision
# bat      292
# field    460
# Name: winner, dtype: int64

# %%
toss_match_winner=matches['team1'].groupby([matches['winner'],matches['toss_winner']]).count()

# %%
toss_match_winner
# Out:
# winner               toss_winner
# Chennai Super Kings  Chennai Super Kings            57
#                      Deccan Chargers                 2
#                      Delhi Capitals                  7
#                      Kings XI Punjab                 3
#                      Kolkata Knight Riders           6
#                                                     ..
# Sunrisers Hyderabad  Mumbai Indians                  5
#                      Pune Warriors                   2
#                      Rajasthan Royals                3
#                      Royal Challengers Bangalore     6
#                      Sunrisers Hyderabad            23
# Name: team1, Length: 113, dtype: int64

# %%
toss_match_winner.unstack().head()
# Out:
# toss_winner          Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# winner
# Chennai Super Kings                 57.0              2.0             7.0
# Deccan Chargers                      1.0             19.0             NaN
# Delhi Capitals                       4.0              5.0            42.0
# Gujarat Lions                        NaN              NaN             1.0
# Kings XI Punjab                      5.0              3.0             8.0
#
# toss_winner          Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# winner
# Chennai Super Kings            NaN              3.0                   NaN
# Deccan Chargers                NaN              2.0                   1.0
# Delhi Capitals                 NaN              3.0                   NaN
# Gujarat Lions                 10.0              NaN                   NaN
# Kings XI Punjab                2.0             35.0                   NaN
#
# ...

# %%
x=toss_match_winner.reset_index()

# %%
x
# Out:
#                   winner                  toss_winner  team1
# 0    Chennai Super Kings          Chennai Super Kings     57
# 1    Chennai Super Kings              Deccan Chargers      2
# 2    Chennai Super Kings               Delhi Capitals      7
# 3    Chennai Super Kings              Kings XI Punjab      3
# 4    Chennai Super Kings        Kolkata Knight Riders      6
# ..                   ...                          ...    ...
# 108  Sunrisers Hyderabad               Mumbai Indians      5
# 109  Sunrisers Hyderabad                Pune Warriors      2
# 110  Sunrisers Hyderabad             Rajasthan Royals      3
# 111  Sunrisers Hyderabad  Royal Challengers Bangalore      6
# 112  Sunrisers Hyderabad          Sunrisers Hyderabad     23
#
# [113 rows x 3 columns]

# %%
df1 = x.loc[x['winner'] == x['toss_winner']]

# %%
df1
# Out:
#                           winner                  toss_winner  team1
# 0            Chennai Super Kings          Chennai Super Kings     57
# 11               Deccan Chargers              Deccan Chargers     19
# 19                Delhi Capitals               Delhi Capitals     42
# 29                 Gujarat Lions                Gujarat Lions     10
# 36               Kings XI Punjab              Kings XI Punjab     35
# 44          Kochi Tuskers Kerala         Kochi Tuskers Kerala      4
# 50         Kolkata Knight Riders        Kolkata Knight Riders     53
# 62                Mumbai Indians               Mumbai Indians     56
# 74                 Pune Warriors                Pune Warriors      3
# 83              Rajasthan Royals             Rajasthan Royals     42
# 88        Rising Pune Supergiant       Rising Pune Supergiant      8
# 102  Royal Challengers Bangalore  Royal Challengers Bangalore     41
# 112          Sunrisers Hyderabad          Sunrisers Hyderabad     23

# %%
d=toss_winners.to_numpy()

# %%
d
# Out:
# array([89, 43, 90, 15, 81,  8, 92, 98, 20, 80, 13, 81, 46], dtype=int64)

# %%
df1['Team']=d
# Out:
# <ipython-input-425-76855940d1fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Team']=d

# %%
df1=df1.drop(columns='winner')

# %%
df1.columns=['Teams','Win+Toss Won','Toss Won']

# %%
df1['%(win+toss_won)']=(df1['Win+Toss Won']/df1['Toss Won'])*100

# %%
df1['total_matches']=total_matches.to_numpy()

# %%
df1.head()
# Out:
#                   Teams  Win+Toss Won  Toss Won  %(win+toss_won)  \
# 0   Chennai Super Kings            57        89        64.044944
# 11      Deccan Chargers            19        43        44.186047
# 19       Delhi Capitals            42        90        46.666667
# 29        Gujarat Lions            10        15        66.666667
# 36      Kings XI Punjab            35        81        43.209877
#
#     total_matches
# 0             164
# 11             75
# 19            177
# 29             30
# 36            176

# %%
plt.figure(figsize=(9,7))
sns.barplot(x=df1['Win+Toss Won'],y=df1['Teams'],data=df1,orient='h')
# Out:
# <AxesSubplot:xlabel='Win+Toss Won', ylabel='Teams'>

# %%
plt.figure(figsize=(9,7))
ax2=sns.barplot(x=df1['Teams'],y=df1['%(win+toss_won)'],palette='plasma').set_xticklabels(df1['Teams'],rotation=90)

# %%
df1.loc[df1['Win+Toss Won'].argmax()]['Teams']
# Out:
# 'Chennai Super Kings'

# %%
MOM=matches['player_of_match'].groupby(matches['player_of_match']).count()

# %%
MOM.head()
# Out:
# player_of_match
# A Chandila     1
# A Joseph       1
# A Kumble       3
# A Mishra      11
# A Nehra        6
# Name: player_of_match, dtype: int64

# %%
MOM.sort_values(ascending=False,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=MOM.head().index,y=MOM.head(),palette='Set1')
plt.xlabel("Players",size=20)
plt.ylabel('Awards',size=20)
plt.title("Tops Five Players With Most Man Of The Match Awards",size=20)
# Out:
# Text(0.5, 1.0, 'Tops Five Players With Most Man Of The Match Awards')

# %% [markdown]
# CHRIS GAYLE WON THE MOST NO OF MAN OF THE MATCH AWARDS = 21

# %%
venue=matches['venue'].groupby(matches.venue).count()

# %%
venue.nunique()
# Out:
# 22

# %%
venue.sort_values(ascending=False).head()
# Out:
# venue
# Eden Gardens                                 77
# Wankhede Stadium                             73
# M Chinnaswamy Stadium                        73
# Feroz Shah Kotla                             67
# Rajiv Gandhi International Stadium, Uppal    56
# Name: venue, dtype: int64

# %%
venue[venue==venue.max()].index[0]
# Out:
# 'Eden Gardens'

# %%
plt.figure(figsize=(10,7))
venue.sort_values(ascending=False).head(10).plot(kind='bar')
plt.show()

# %% [markdown]
# MOST NO OF MATCHES WERE PLAYED IN THE VENUE "EDEN GARDENS" = 77

# %%
matches[matches['dl_applied']==1]['player_of_match'].count()
# Out:
# 19

# %% [markdown]
#  IN 19 MATCHES THE  'duckworth lewis'  RULE WAS APPLIED

# %% [markdown]
# # Information About Players

# %%
players.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy  24-Feb-91   Right_Hand      Right-arm medium   India
# 1      A Chandila  05-Dec-83   Right_Hand    Right-arm offbreak   India
# 2        A Chopra  19-Sep-77   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaN   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaN   Right_Hand    Right-arm offbreak     NaN

# %%
players['Country'].nunique()
# Out:
# 11

# %% [markdown]
# Players from 11 countries participate in The Indian Premier League

# %%
Country=players['Country'].groupby(players['Country']).count()

# %%
Country
# Out:
# Country
# Australia        72
# Bangladesh        5
# England          14
# India           264
# Netherlands       1
# New Zealand      22
# Pakistan         13
# South Africa     39
# Sri Lanka        20
# West Indies      19
# Zimbabwea         2
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(8,7))
Country.plot(kind='bar')
plt.show()

# %%
#Percentage of Indian Players in the League
(Country['India'].sum()/Country.sum())*100
# Out:
# 56.05095541401274

# %%
players['Batting_Hand'].replace(to_replace="Right_hand",value="Right_Hand",inplace=True)

# %%
Batting_Hand=players['Batting_Hand'].groupby(players['Batting_Hand']).count()

# %%
Batting_Hand
# Out:
# Batting_Hand
# Left_Hand     142
# Right_Hand    421
# Name: Batting_Hand, dtype: int64

# %% [raw]
# players['Bowling_Skill'].nunique()

# %%
bowling=players['Bowling_Skill'].groupby(players['Bowling_Skill']).count()

# %%
bowling.head()
# Out:
# Bowling_Skill
# Left-arm fast            4
# Left-arm fast-medium    19
# Left-arm medium         11
# Left-arm medium-fast     9
# Legbreak                30
# Name: Bowling_Skill, dtype: int64

# %%
#Five most common bowling style
bowling.sort_values(ascending=False).head()
# Out:
# Bowling_Skill
# Right-arm medium          107
# Right-arm offbreak         91
# Right-arm fast-medium      68
# Slow left-arm orthodox     50
# Right-arm fast             39
# Name: Bowling_Skill, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.xlabel('bowling[bowling>35].index',size=20)
plt.ylabel('Frequency',size=20)
ax3=sns.barplot(x=bowling[bowling>35].index,y=bowling[bowling>35],data=bowling,palette='RdYlBu')
ax3.set(ylabel='Frequency')
ax4=ax3.set_xticklabels(bowling[bowling>35].index,rotation=90,size=15)

# %%
runs.head(10)
# Out:
#           batsman  total_runs  out  numberofballs    average  strikerate
# 0         V Kohli        5426  152           4111  35.697368  131.987351
# 1        SK Raina        5386  160           3916  33.662500  137.538304
# 2       RG Sharma        4902  161           3742  30.447205  130.999466
# 3       DA Warner        4717  114           3292  41.377193  143.286756
# 4        S Dhawan        4601  137           3665  33.583942  125.538881
# 5        CH Gayle        4525  110           2972  41.136364  152.254374
# 6        MS Dhoni        4450  118           3206  37.711864  138.802246
# 7      RV Uthappa        4420  156           3381  28.333333  130.730553
# 8  AB de Villiers        4414  104           2902  42.442308  152.101999
# 9       G Gambhir        4219  134           3400  31.485075  124.088235

# %%
runs['batsman'].nunique()
# Out:
# 516

# %%
batsman=runs[['batsman','total_runs','strikerate']]

# %% [markdown]
# Top 10 Batsman

# %%
batsman.head(10)
# Out:
#           batsman  total_runs  strikerate
# 0         V Kohli        5426  131.987351
# 1        SK Raina        5386  137.538304
# 2       RG Sharma        4902  130.999466
# 3       DA Warner        4717  143.286756
# 4        S Dhawan        4601  125.538881
# 5        CH Gayle        4525  152.254374
# 6        MS Dhoni        4450  138.802246
# 7      RV Uthappa        4420  130.730553
# 8  AB de Villiers        4414  152.101999
# 9       G Gambhir        4219  124.088235

# %%
sns.jointplot(x='total_runs',y='numberofballs',data=runs)

# %% [markdown]
# Batsmen with min strike rate of 100,min 1000 runs scored and have min average of 30+

# %%
df2=runs[runs['strikerate']>100]

# %%
df2=df2[df2['total_runs']>1000]

# %%
df2=df2[df2['average']>30]

# %%
len(df2)
# Out:
# 32

# %%
df2.sort_values('total_runs',axis=0,ascending=False,inplace=True)

# %%
df2.head()
# Out:
#      batsman  total_runs  out  numberofballs    average  strikerate
# 0    V Kohli        5426  152           4111  35.697368  131.987351
# 1   SK Raina        5386  160           3916  33.662500  137.538304
# 2  RG Sharma        4902  161           3742  30.447205  130.999466
# 3  DA Warner        4717  114           3292  41.377193  143.286756
# 4   S Dhawan        4601  137           3665  33.583942  125.538881

# %% [markdown]
# TOP 10 Batsman

# %%
plt.figure(figsize=(12,8))
plt.xlabel('Batsman',size=20)
plt.ylabel('StrikeRate',size=20)
ax4=sns.barplot(x=df2['batsman'].head(10),y=df2['strikerate'].head(10),palette='viridis').set_xticklabels(df2['batsman'].head(10),rotation=90)

# %% [markdown]
# Bottom 10 Batsman

# %%
plt.figure(figsize=(12,8))
plt.xlabel('Batsman',size=20)
plt.ylabel('StrikeRate',size=20)
ax4=sns.barplot(x=df2['batsman'].tail(10),y=df2['strikerate'].tail(10),palette='rainbow').set_xticklabels(df2['batsman'].tail(10),rotation=90)

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(12,8))
batsman.head(10).boxplot(column='total_runs', ax=ax[0],color='red')
batsman.head(10).boxplot(column='strikerate',ax=ax[1],color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analyzing Deliveries data set

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.dismissal_kind.nunique()
# Out:
# 9

# %%
ax=sns.countplot(x=deliveries['dismissal_kind'],data=deliveries)
ax.figure.set_size_inches(15,8)
plt.xlabel('Dismissal Kind',size=20)
plt.ylabel('Count',size=20)
plt.title('Distribution of Dismissals ',size=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Dismissals ')

# %% [markdown]
# Distribution of Extras Runs

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dfr=(deliveries['dismissal_kind']=='caught').groupby(deliveries['fielder']).sum()

# %%
dfr.sort_values(ascending=False,inplace=True)

# %%
#Most Catches
dfr[:10]
# Out:
# fielder
# KD Karthik        109
# SK Raina           99
# MS Dhoni           98
# AB de Villiers     93
# RV Uthappa         84
# RG Sharma          82
# KA Pollard         76
# V Kohli            73
# PA Patel           69
# S Dhawan           68
# Name: dismissal_kind, dtype: int64

# %%
extras=pd.DataFrame()

# %%
extras['Wide_Runs']=deliveries['wide_runs'].groupby(deliveries['wide_runs']).sum()

# %%
extras['Wide_Runs']=extras.Wide_Runs.sum()

# %%
extras['Wide_Runs']=extras.Wide_Runs[:1]

# %%
extras['bye_runs']=deliveries['bye_runs'].groupby(deliveries['bye_runs']).sum()

# %%
extras['bye_runs']=extras.bye_runs.sum()
extras['bye_runs']=extras.bye_runs[:1]

# %%
extras['legbye_runs']=deliveries['legbye_runs'].groupby(deliveries['legbye_runs']).sum()
extras['legbye_runs']=extras.legbye_runs.sum()
extras['legbye_runs']=extras.legbye_runs[:1]

# %%
extras['noball_runs']=deliveries['noball_runs'].groupby(deliveries['noball_runs']).sum()
extras['noball_runs']=extras.noball_runs.sum()
extras['noball_runs']=extras.noball_runs[:1]

# %%
extras.index.names=[' ']

# %%
extras.dropna(inplace=True)

# %%
extras.transpose().plot(kind='bar')
plt.rc('xtick', labelsize=10)
plt.show()

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
sixes=(deliveries['batsman_runs']==6).groupby(deliveries['batsman']).sum()

# %%
sixes.head()
# Out:
# batsman
# A Ashish Reddy    15
# A Chandila         0
# A Chopra           0
# A Choudhary        1
# A Dananjaya        0
# Name: batsman_runs, dtype: int64

# %%
total_sixes=sixes.sum()

# %%
total_sixes
# Out:
# 8170

# %%
sixes[sixes==sixes.max()]
# Out:
# batsman
# CH Gayle    327
# Name: batsman_runs, dtype: int64

# %%
fours=(deliveries['batsman_runs']==4).groupby(deliveries['batsman']).sum()

# %%
total_fours=fours.sum()

# %%
total_fours
# Out:
# 20392

# %%
fours[fours==fours.max()]
# Out:
# batsman
# S Dhawan    526
# Name: batsman_runs, dtype: int64

# %%
total_runs=deliveries['total_runs'].sum()

# %%
total_runs
# Out:
# 235290

# %%
df4=batsman

# %%
l=list(batsman.batsman)

# %%
a=list()
for i in l:
    a.append(fours[i])

# %%
df4['4s']=a
# Out:
# <ipython-input-505-25b24e3ac29f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['4s']=a

# %%
df4.head()
# Out:
#      batsman  total_runs  strikerate   4s
# 0    V Kohli        5426  131.987351  482
# 1   SK Raina        5386  137.538304  495
# 2  RG Sharma        4902  130.999466  431
# 3  DA Warner        4717  143.286756  459
# 4   S Dhawan        4601  125.538881  526

# %%
b=list()
for i in l:
    b.append(sixes[i])

# %%
df4['6s']=b
# Out:
# <ipython-input-508-907085ce7f82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['6s']=b

# %%
df4.head()
# Out:
#      batsman  total_runs  strikerate   4s   6s
# 0    V Kohli        5426  131.987351  482  191
# 1   SK Raina        5386  137.538304  495  195
# 2  RG Sharma        4902  130.999466  431  194
# 3  DA Warner        4717  143.286756  459  181
# 4   S Dhawan        4601  125.538881  526   96

# %%
df4['boundary%']=((df4['4s']+df4['6s'])/df4['total_runs'])*100

# %%
df4.head(10)
# Out:
#           batsman  total_runs  strikerate   4s   6s  boundary%
# 0         V Kohli        5426  131.987351  482  191  12.403244
# 1        SK Raina        5386  137.538304  495  195  12.810991
# 2       RG Sharma        4902  130.999466  431  194  12.749898
# 3       DA Warner        4717  143.286756  459  181  13.567946
# 4        S Dhawan        4601  125.538881  526   96  13.518800
# 5        CH Gayle        4525  152.254374  376  327  15.535912
# 6        MS Dhoni        4450  138.802246  297  207  11.325843
# 7      RV Uthappa        4420  130.730553  436  156  13.393665
# 8  AB de Villiers        4414  152.101999  357  214  12.936112
# 9       G Gambhir        4219  124.088235  492   59  13.059967

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='boundary%',y='strikerate',data=df4)
# Out:
# <AxesSubplot:xlabel='boundary%', ylabel='strikerate'>

# %%
df5=df4[df4['total_runs']>3000]

# %%
df5.sort_values('boundary%',ascending=False,inplace=True)
# Out:
# <ipython-input-514-9cc96275cd47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.sort_values('boundary%',ascending=False,inplace=True)

# %%
df5.head(10)
# Out:
#            batsman  total_runs  strikerate   4s   6s  boundary%
# 5         CH Gayle        4525  152.254374  376  327  15.535912
# 12       SR Watson        3590  139.906469  344  177  14.512535
# 3        DA Warner        4717  143.286756  459  181  13.567946
# 4         S Dhawan        4601  125.538881  526   96  13.518800
# 7       RV Uthappa        4420  130.730553  436  156  13.393665
# 14       YK Pathan        3222  143.839286  264  161  13.190565
# 9        G Gambhir        4219  124.088235  492   59  13.059967
# 8   AB de Villiers        4414  152.101999  357  214  12.936112
# 1         SK Raina        5386  137.538304  495  195  12.810991
# 2        RG Sharma        4902  130.999466  431  194  12.749898

# %%
plt.figure(figsize=(8,5))
plt.xlabel('batsman',size=20)
plt.ylabel('boundary%',size=20)
plt.title('Top 10 batsman by boundary percentage',size=20)
ax=sns.barplot(x='batsman',y='boundary%',data=df5.head(10)).set_xticklabels(df5.batsman.head(10),rotation=90)

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
overs=deliveries.groupby(deliveries['match_id']).agg('count')

# %%
overs=overs.reset_index()

# %%
runs=deliveries.groupby(deliveries['match_id']).sum()

# %%
runs=runs.reset_index()

# %%
df6=pd.DataFrame(overs.match_id)

# %%
df6['overs']=overs['over']//6
df6['runs']=runs['total_runs']

# %%
df6['run_rate']=df6['runs']/df6['overs']

# %%
df6.head()
# Out:
#    match_id  overs  runs   run_rate
# 0         1     41   379   9.243902
# 1         2     41   371   9.048780
# 2         3     36   367  10.194444
# 3         4     41   327   7.975610
# 4         5     41   299   7.292683

# %%
sns.displot(df6['runs'],kde=True)
plt.xlabel('Runs',size=20)
# Out:
# Text(0.5, 6.799999999999997, 'Runs')

# %%
plt.hist(df6['run_rate'])
plt.show()

# %%
matches.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.id.nunique()
# Out:
# 756

# %%
deliveries.match_id.nunique()
# Out:
# 756

# %%
deliveries.rename(columns={'match_id': 'id'},inplace=True)

# %%
deliveries.head()
# Out:
#    id  inning         batting_team                 bowling_team  over  ball  \
# 0   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1
# 1   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2
# 2   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3
# 3   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4
# 4   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5
#
#      batsman non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 1  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 2  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 3  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 4  DA Warner    S Dhawan  TS Mills              0  ...         0            0
#
# ...

# %%
d=matches[['id','Season','winner','player_of_match']]

# %%
d.head()
# Out:
#    id    Season                       winner player_of_match
# 0   1  IPL-2017          Sunrisers Hyderabad    Yuvraj Singh
# 1   2  IPL-2017       Rising Pune Supergiant       SPD Smith
# 2   3  IPL-2017        Kolkata Knight Riders         CA Lynn
# 3   4  IPL-2017              Kings XI Punjab      GJ Maxwell
# 4   5  IPL-2017  Royal Challengers Bangalore       KM Jadhav

# %%
df7=pd.merge(deliveries,d,how='inner',on='id')

# %%
df7.drop(['non_striker','penalty_runs','extra_runs','player_dismissed','dismissal_kind','fielder','is_super_over','wide_runs','bye_runs','legbye_runs','noball_runs'],axis=1,inplace=True)

# %%
df7.head()
# Out:
#    id  inning         batting_team                 bowling_team  over  ball  \
# 0   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1
# 1   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2
# 2   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3
# 3   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4
# 4   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5
#
#      batsman    bowler  batsman_runs  total_runs    Season  \
# 0  DA Warner  TS Mills             0           0  IPL-2017
# 1  DA Warner  TS Mills             0           0  IPL-2017
# 2  DA Warner  TS Mills             4           4  IPL-2017
# 3  DA Warner  TS Mills             0           0  IPL-2017
# 4  DA Warner  TS Mills             0           2  IPL-2017
#
#                 winner player_of_match
# 0  Sunrisers Hyderabad    Yuvraj Singh
# 1  Sunrisers Hyderabad    Yuvraj Singh
# ...

# %%
season_2019=df7[df7['Season'].astype(str).str.contains('2019')]

# %%
season_2019.head()
# Out:
#            id  inning                 batting_team         bowling_team  over  \
# 164750  11137       1  Royal Challengers Bangalore  Chennai Super Kings     1
# 164751  11137       1  Royal Challengers Bangalore  Chennai Super Kings     1
# 164752  11137       1  Royal Challengers Bangalore  Chennai Super Kings     1
# 164753  11137       1  Royal Challengers Bangalore  Chennai Super Kings     1
# 164754  11137       1  Royal Challengers Bangalore  Chennai Super Kings     1
#
#         ball   batsman     bowler  batsman_runs  total_runs    Season  \
# 164750     1   V Kohli  DL Chahar             1           1  IPL-2019
# 164751     2  PA Patel  DL Chahar             0           0  IPL-2019
# 164752     3  PA Patel  DL Chahar             0           0  IPL-2019
# 164753     4  PA Patel  DL Chahar             0           0  IPL-2019
# 164754     5  PA Patel  DL Chahar             4           4  IPL-2019
#
#                      winner  player_of_match
# ...

# %%
#total runs scored in Season 2019
season_2019['total_runs'].sum()
# Out:
# 20270

# %%
runs2019=season_2019['batsman_runs'].groupby([season_2019['batsman'],season_2019['batting_team']]).sum()

# %%
#Top Scorer
runs2019[runs2019==runs2019.max()]
# Out:
# batsman    batting_team
# DA Warner  Sunrisers Hyderabad    727
# Name: batsman_runs, dtype: int64

# %%
runs2019.sort_values(ascending=False,inplace=True)

# %%
#Top 10 Scores of IPL 2019
runs2019.head(10)
# Out:
# batsman     batting_team
# DA Warner   Sunrisers Hyderabad            727
# KL Rahul    Kings XI Punjab                610
# Q de Kock   Mumbai Indians                 555
# AD Russell  Kolkata Knight Riders          545
# S Dhawan    Delhi Capitals                 542
# CH Gayle    Kings XI Punjab                523
# RR Pant     Delhi Capitals                 511
# SS Iyer     Delhi Capitals                 484
# V Kohli     Royal Challengers Bangalore    472
# J Bairstow  Sunrisers Hyderabad            468
# Name: batsman_runs, dtype: int64

# %%
teamss=season_2019['total_runs'].groupby(season_2019['batting_team']).sum()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=teamss,y=teamss.index,orient='h')
# Out:
# <AxesSubplot:xlabel='total_runs', ylabel='batting_team'>

# %%
overss=season_2019['ball'].groupby(season_2019['batting_team']).count()

# %%
overss.head()
# Out:
# batting_team
# Chennai Super Kings      2051
# Delhi Capitals           1909
# Kings XI Punjab          1720
# Kolkata Knight Riders    1703
# Mumbai Indians           1946
# Name: ball, dtype: int64

# %%
over2019=overss//6

# %%
df8=pd.DataFrame()

# %%
df8['Teams']=season_2019['batting_team'].unique()

# %%
df8.insert(1,'Runs',value=True)

# %%
df8.head()
# Out:
#                          Teams  Runs
# 0  Royal Challengers Bangalore  True
# 1          Chennai Super Kings  True
# 2          Sunrisers Hyderabad  True
# 3        Kolkata Knight Riders  True
# 4               Delhi Capitals  True

# %%
t=season_2019['batting_team'].unique()

# %%
t
# Out:
# array(['Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Sunrisers Hyderabad', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'Mumbai Indians', 'Kings XI Punjab', 'Rajasthan Royals'],
#       dtype=object)

# %%
t1=list()
for i in t:
    t1.append(teamss[i])

# %%
df8['Runs']=t1

# %%
t2=list()
for i in t:
    t2.append(over2019[i])

# %%
df8['Overs']=t2

# %%
df8['Run Rate']=df8['Runs']/df8['Overs']

# %%
df8.sort_values('Runs',ascending=False,inplace=True)

# %%
df8.head()
# Out:
#                    Teams  Runs  Overs  Run Rate
# 5         Mumbai Indians  2783    324  8.589506
# 4         Delhi Capitals  2630    318  8.270440
# 1    Chennai Super Kings  2599    341  7.621701
# 3  Kolkata Knight Riders  2591    283  9.155477
# 2    Sunrisers Hyderabad  2565    296  8.665541

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x="Runs", y="Run Rate", hue="Teams", data=df8,legend='full')
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))

# %% [markdown]
# Virat Kohli   and   M S Dhoni

# %%
deliveries.head()
# Out:
#    id  inning         batting_team                 bowling_team  over  ball  \
# 0   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1
# 1   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2
# 2   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3
# 3   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4
# 4   1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5
#
#      batsman non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 1  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 2  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 3  DA Warner    S Dhawan  TS Mills              0  ...         0            0
# 4  DA Warner    S Dhawan  TS Mills              0  ...         0            0
#
# ...

# %%
kohli=deliveries[deliveries['batsman']=='V Kohli']

# %%
virat_first=kohli[kohli['inning']==1]

# %%
virat_first_runs=virat_first.groupby(virat_first['id']).agg('sum')

# %%
virat_second=kohli[kohli['inning']==2]

# %%
virat_second_runs=virat_second.groupby(virat_second['id']).sum()

# %%
plt.figure(figsize=(8,8))
first=virat_first_runs['batsman_runs']
second=virat_second_runs['batsman_runs']
legend=['1st Innings','2nd Innings']
plt.hist([first,second])
plt.legend(legend)
plt.xlabel("Runs")
plt.ylabel('Frequncy')
plt.title('Virat Kohli\'s Runs Contribution')
# Out:
# Text(0.5, 1.0, "Virat Kohli's Runs Contribution")

# %%
virat_first_runs=virat_first_runs.reset_index()
virat_second_runs=virat_second_runs.reset_index()

# %%
win=[]

for i in virat_first_runs['id']:
    x=(matches[matches['id']==i])
    y=list(x['winner'])
    if y:
        if y[0]=='Royal Challengers Bangalore':
            win.append('Victory')
        else:
            win.append('Defeat')
    else:
        win.append('No Result')

# %%
virat_first_runs['Result']=win

# %%
virat_first_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0  12      48   395   161              0          1         0            0
# 1  20      51   398   171              0          1         0            0
# 2  30      14    37    54              0          1         0            1
# 3  37      15    56    35              0          1         0            0
# 4  45       9    16    31              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs   Result
# 0            0             0            62           1          63   Defeat
# 1            0             0            64           1          65  Victory
# 2            0             0            10           2          12   Defeat
# 3            0             0            20           1          21   Defeat
# 4            0             0             5           0           5   Defeat

# %%
wins=[]
for i in virat_second_runs['id']:
    x=matches[matches['id']==i]
    y=list(x['winner'])
    if y:
        if y[0]=='Royal Challengers Bangalore':
            wins.append('Victory')
        else:
            wins.append('Defeat')
    else:
        wins.append('No Result')

# %%
virat_second_runs['Result']=wins

# %%
virat_first_victory=virat_first_runs[virat_first_runs['Result']=='Victory']
virat_first_defeat=virat_first_runs[virat_first_runs['Result']=='Defeat']
virat_second_victory=virat_first_runs[virat_second_runs['Result']=='Victory']
virat_second_defeat=virat_first_runs[virat_second_runs['Result']=='Defeat']
# Out:
# <ipython-input-577-4d38478ca813>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   virat_second_victory=virat_first_runs[virat_second_runs['Result']=='Victory']
# <ipython-input-577-4d38478ca813>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   virat_second_defeat=virat_first_runs[virat_second_runs['Result']=='Defeat']

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,10))
first=virat_first_victory['batsman_runs']
second=virat_second_victory['batsman_runs']
legend=['1\'s Innings','2\'s Innings']
ax[0].hist([first,second])
ax[0].legend(legend)
ax[0].set_title('Kohli\'s Victory Summary',size=20)
ax[0].set_xlabel('Runs',size=20)
ax[0].set_ylabel('Frequency',size=20)
first=virat_first_defeat['batsman_runs']
second=virat_second_defeat['batsman_runs']
ax[1].hist([first,second])
ax[1].legend(legend)
ax[1].set_title('Kohli\'s Defeat Summary',size=20)
ax[1].set_xlabel('Runs',size=20)
ax[1].set_ylabel('Frequency',size=20)

#one of the greatest run chaser
# Out:
# Text(0, 0.5, 'Frequency')

# %%
runs1=(deliveries['total_runs']).groupby([deliveries['id'],deliveries['batting_team']]).sum()

# %%
runs1=runs1.unstack()

# %%
runs1=runs1.reset_index()

# %%
t=[]
for i in virat_first_runs.id:
    x=runs1[runs1['id']==i]['Royal Challengers Bangalore']
    t.append(int(x.to_numpy()[0]))

# %%
virat_first_runs['Team Total']=t
virat_first_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0  12      48   395   161              0          1         0            0
# 1  20      51   398   171              0          1         0            0
# 2  30      14    37    54              0          1         0            1
# 3  37      15    56    35              0          1         0            0
# 4  45       9    16    31              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs   Result  \
# 0            0             0            62           1          63   Defeat
# 1            0             0            64           1          65  Victory
# 2            0             0            10           2          12   Defeat
# 3            0             0            20           1          21   Defeat
# 4            0             0             5           0           5   Defeat
#
#    Team Total
# 0         142
# 1         213
# ...

# %%
t1=[]
for i in virat_second_runs.id:
    x=runs1[runs1['id']==i]['Royal Challengers Bangalore']
    t1.append(int(x.to_numpy()[0]))

# %%
virat_second_runs['Team Total']=t1
virat_second_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0  17      38    63    55              0          0         0            0
# 1  27       2     1     4              0          0         0            0
# 2  33      96   462   148              0          0         0            0
# 3  42      12    12    31              0          0         0            0
# 4  60      10    12    12              0          0         0            4
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  Result  \
# 0            0             0            28           0          28  Defeat
# 1            0             0             0           0           0  Defeat
# 2            0             0            55           0          55  Defeat
# 3            0             0             6           0           6  Defeat
# 4            0             0             1           4           5  Defeat
#
#    Team Total
# 0         134
# 1          49
# 2          96
# ...

# %%
virat_first_runs['Run Contribution']=(virat_first_runs['batsman_runs']/virat_first_runs['Team Total'])*100
virat_second_runs['Run Contribution']=(virat_second_runs['batsman_runs']/virat_second_runs['Team Total'])*100

# %%
kohli_wins=pd.concat([virat_first_runs[virat_first_runs['Result']=='Victory'],virat_second_runs[virat_second_runs['Result']=='Victory']])

# %%
kohli_defeat=pd.concat([virat_first_runs[virat_first_runs['Result']=='Defeat'],virat_second_runs[virat_second_runs['Result']=='Defeat']])

# %%
kohli_wins.head()
# Out:
#      id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 1    20      51   398   171              0          1         0            0
# 5    55      46   519   162              0          1         0            0
# 10  107      17    99    65              0          1         0            1
# 11  111      31   268   112              0          2         0            0
# 12  119       8    86    35              0          0         0            0
#
#     noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs   Result  \
# 1             0             0            64           1          65  Victory
# 5             0             0            58           1          59  Victory
# 10            0             0            10           2          12  Victory
# 11            0             0            38           2          40  Victory
# 12            0             0             3           0           3  Victory
#
#     Team Total  Run Contribution
# ...

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,8))
ax1.violinplot(kohli_wins['Run Contribution'])
ax1.set_title('Virat Kohli\'s Run Contribution In Victory')
ax2.violinplot(kohli_defeat['Run Contribution'])
ax2.set_title('Virat Kohli\'s Run Contribution In Defeat')
# Out:
# Text(0.5, 1.0, "Virat Kohli's Run Contribution In Defeat")

# %%
virat_first_runs['ball']=virat_first.groupby(virat_first['id']).count()['over'].to_numpy()
virat_second_runs['ball']=virat_second.groupby(virat_second['id']).count()['over'].to_numpy()

# %%
virat_first_runs['Strike Rate']=(virat_first_runs['batsman_runs']/virat_first_runs['ball'])*100
virat_second_runs['Strike Rate']=(virat_second_runs['batsman_runs']/virat_second_runs['ball'])*100

# %%
Virat_Kohli=pd.concat([virat_first_runs,virat_second_runs])

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Run Contribution',y='Strike Rate',hue='Result',data=Virat_Kohli,legend='full')
# Out:
# <AxesSubplot:xlabel='Run Contribution', ylabel='Strike Rate'>

# %% [markdown]
# MS DHONI

# %%
dhoni=deliveries[deliveries['batsman']=='MS Dhoni']

# %%
dhoni_first=dhoni[dhoni['inning']==1]
dhoni_first_runs=dhoni_first.groupby('id').sum()

# %%
dhoni_second=dhoni[dhoni['inning']==2]
dhoni_second_runs=dhoni_second.groupby('id').sum()

# %%
plt.figure(figsize=(8,8))
first=dhoni_first_runs['batsman_runs']
second=dhoni_second_runs['batsman_runs']
legend=(['1\'s Innings','2\'s Innings'])
plt.hist([first,second])
plt.legend(legend)
plt.xlabel('Runs')
plt.ylabel('Frequency')
plt.title('MS Dhoni\'s Run Contribution')
# Out:
# Text(0.5, 1.0, "MS Dhoni's Run Contribution")

# %%
dhoni_first_runs=dhoni_first_runs.reset_index()
dhoni_second_runs=dhoni_second_runs.reset_index()

# %%
win=[]
for i in dhoni_first_runs['id']:
    x = matches[matches['id']==i]
    y=list(x['winner'])
    if y:
        if y[0]=='Chennai Super Kings':
            win.append('Victory')
        else:
            win.append('Defeat')
    else:
        win.append('No Result')

# %%
dhoni_first_runs['Result']=win

# %%
wins=[]
for i in dhoni_second_runs['id']:
    x=matches[matches['id']==i]
    y=list(x['winner'])
    if y:
        if y[0]=='Chennai Super Kings':
            wins.append('Victory')
        else:
            wins.append('Defeat')
    else:
        wins.append('No Result')

# %%
dhoni_second_runs['Result']=wins

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,10))
first=dhoni_first_runs[dhoni_first_runs['Result']=='Victory']['batsman_runs']
second=dhoni_second_runs[dhoni_second_runs['Result']=='Victory']['batsman_runs']
legend=(['1\'s Innings','2\'s Innings'])
ax[0].hist([first,second])
ax[0].legend(legend)
ax[0].set_title('Dhoni\'s Victory Summary',size=20)
ax[0].set_xlabel('Runs',size=20)
ax[0].set_ylabel('Frequency',size=20)
first=dhoni_first_runs[dhoni_first_runs['Result']=='Defeat']['batsman_runs']
second=dhoni_second_runs[dhoni_second_runs['Result']=='Defeat']['batsman_runs']
legend=(['1\'s Innings','2\'s Innings'])
ax[1].hist([first,second])
ax[1].legend(legend)
ax[1].set_title('Dhoni\'s Defeat Summary',size=20)
ax[1].set_xlabel('Runs',size=20)
ax[1].set_ylabel('Frequency',size=20)

#overall a great finisher
# Out:
# Text(0, 0.5, 'Frequency')

# %%
t=[]
for i in dhoni_first_runs.id:
    x=runs1[runs1['id']==i][['Chennai Super Kings','Rising Pune Supergiant']]
    if str(runs1[runs1['id']==i]['Chennai Super Kings'].to_numpy()[0])=='nan':
        t.append(x.to_numpy()[0][1])
    else:
        t.append(x.to_numpy()[0][0])

# %%
dhoni_first_runs['Team Total']=t

# %%
dhoni_first_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0   4      13   134    48              0          2         0            0
# 1  13       8   111    27              0          0         0            1
# 2  17      26   315   107              0          1         0            1
# 3  28      11   159    33              0          0         0            0
# 4  29      11   172    45              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  Result  \
# 0            0             0             5           2           7  Defeat
# 1            0             0             5           1           6  Defeat
# 2            0             0            28           2          30  Defeat
# 3            0             0             7           0           7  Defeat
# 4            0             0            23           0          23  Defeat
#
#    Team Total
# 0       163.0
# 1       171.0
# 2       161.0
# ...

# %%
t1=[]
for i in dhoni_second_runs.id:
    x=runs1[runs1['id']==i][['Chennai Super Kings','Rising Pune Supergiant']]
    if str(runs1[runs1['id']==i]['Chennai Super Kings'].to_numpy()[0])=='nan':
        t1.append(x.to_numpy()[0][1])
    else:
        t1.append(x.to_numpy()[0][0])

# %%
dhoni_second_runs['Team Total']=t1

# %%
dhoni_second_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0   2      24   222    37              0          0         0            0
# 1   9      28   139    54              0          0         0            0
# 2  25      70   559   132              0          1         0            0
# 3  38      70   410   134              0          2         0            2
# 4  40      18   140    27              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  Result  \
# 0            0             0            12           0          12  Defeat
# 1            0             0            11           0          11  Defeat
# 2            0             0            61           1          62  Defeat
# 3            0             0            26           4          30  Defeat
# 4            0             0             5           0           5  Defeat
#
#    Team Total
# 0       187.0
# 1       108.0
# 2       179.0
# ...

# %%
dhoni_first_runs['Run Contribution']=(dhoni_first_runs['batsman_runs']/dhoni_first_runs['Team Total'])*100
dhoni_second_runs['Run Contribution']=(dhoni_second_runs['batsman_runs']/dhoni_second_runs['Team Total'])*100

# %%
dhoni_first_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0   4      13   134    48              0          2         0            0
# 1  13       8   111    27              0          0         0            1
# 2  17      26   315   107              0          1         0            1
# 3  28      11   159    33              0          0         0            0
# 4  29      11   172    45              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  Result  \
# 0            0             0             5           2           7  Defeat
# 1            0             0             5           1           6  Defeat
# 2            0             0            28           2          30  Defeat
# 3            0             0             7           0           7  Defeat
# 4            0             0            23           0          23  Defeat
#
#    Team Total  Run Contribution
# ...

# %%
dhoni_wins=pd.concat([dhoni_first_runs[dhoni_first_runs['Result']=='Victory'],dhoni_second_runs[dhoni_second_runs['Result']=='Victory']])
dhoni_defeat=pd.concat([dhoni_first_runs[dhoni_first_runs['Result']=='Victory'],dhoni_second_runs[dhoni_second_runs['Result']=='Victory']])

# %%
dhoni_wins.head()
# Out:
#      id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 8    61       3    22    10              0          0         0            0
# 9    67      17   302    64              0          1         0            1
# 10   74      31   521   115              0          1         0            0
# 14   91      44   620   145              0          1         0            3
# 17  122      15   209    59              0          1         0            0
#
#     noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs   Result  \
# 8             0             0             2           0           2  Victory
# 9             0             0            30           2          32  Victory
# 10            0             0            65           1          66  Victory
# 14            0             0            60           4          64  Victory
# 17            0             0            16           1          17  Victory
#
#     Team Total  Run Contribution
# ...

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,8))
ax1.violinplot(dhoni_wins['Run Contribution'])
ax1.set_title('MS Dhoni\'s Run Contribution In Victory')
ax2.violinplot(dhoni_defeat['Run Contribution'])
ax2.set_title('MS Dhoni\'s Run Contribution In Defeat')
# Out:
# Text(0.5, 1.0, "MS Dhoni's Run Contribution In Defeat")

# %%
dhoni_first_runs['ball']=dhoni_first.groupby(dhoni_first['id']).count()['ball'].to_numpy()
dhoni_second_runs['ball']=dhoni_second.groupby(dhoni_second['id']).count()['ball'].to_numpy()

# %%
dhoni_first_runs['Strike Rate']=(dhoni_first_runs['batsman_runs']/dhoni_first_runs['ball'])*100
dhoni_second_runs['Strike Rate']=(dhoni_second_runs['batsman_runs']/dhoni_first_runs['ball'])*100

# %%
dhoni_first_runs.head()
# Out:
#    id  inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# 0   4      13   134    13              0          2         0            0
# 1  13       8   111     8              0          0         0            1
# 2  17      26   315    26              0          1         0            1
# 3  28      11   159    11              0          0         0            0
# 4  29      11   172    11              0          0         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  Result  \
# 0            0             0             5           2           7  Defeat
# 1            0             0             5           1           6  Defeat
# 2            0             0            28           2          30  Defeat
# 3            0             0             7           0           7  Defeat
# 4            0             0            23           0          23  Defeat
#
#    Team Total  Run Contribution  Strike Rate
# ...

# %%
MSD=pd.concat([dhoni_first_runs,dhoni_second_runs])

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Run Contribution',y='Strike Rate',hue=MSD['Result'],data=MSD,legend="full")
# Out:
# <AxesSubplot:xlabel='Run Contribution', ylabel='Strike Rate'>

# %% [markdown]
# # THANK YOU!!!
